# %%
# to access root modules
if __name__ == "__main__" and __package__ is None:
    from sys import path
    from os.path import dirname as dir

    path.append(dir(path[0]))
    __package__ = "dash_app"

# %%
import pandas as pd
import numpy as np
import datetime
import dateutil
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from charts import stations_map
from settings import *

# %%
data_path = DATA_PATH+'Atmospheric_Domain/2.5Precipitation/Figure2.9/'
xls = pd.ExcelFile(
    data_path+'Annual_rainfall_totals_and_anomalies_OverIreland.xlsx')
dataDF = pd.read_excel(xls, '2010SeasannRR')
dataDF.rename(columns = {
    "Unnamed: 3":"11 Year Moving Average Totals",
    "Unnamed: 4":"Anomaly",
    "11 year moving average":"11 Year Moving Average Anomaly"
    }, inplace = True)
movingAverageTotals = dataDF.ANN.rolling(window=11, center=True).mean() 
dataDF["11 Year Average"]=movingAverageTotals
dataDF[0:20]
# Out:
#      years          ANN      ANNmean  11 Year Moving Average Totals  \
# 0   1940.0          NaN          NaN                            NaN
# 1   1941.0  1014.194566  1186.913018                            NaN
# 2   1942.0  1147.460488  1186.913018                            NaN
# 3   1943.0  1195.976899  1186.913018                            NaN
# 4   1944.0  1174.911879  1186.913018                            NaN
# 5   1945.0  1129.928436  1186.913018                            NaN
# 6   1946.0  1306.190295  1186.913018                    1210.168840
# 7   1947.0  1307.326269  1186.913018                    1208.243051
# 8   1948.0  1316.762070  1186.913018                    1196.707751
# 9   1949.0  1136.678395  1186.913018                    1213.981397
# 10  1950.0  1312.113645  1186.913018                    1202.397905
# 11  1951.0  1270.314294  1186.913018                    1205.036357
# 12  1952.0   993.010893  1186.913018                    1193.327942
# 13  1953.0  1020.572182  1186.913018                    1195.791639
# 14  1954.0  1385.987007  1186.913018                    1180.391173
# 15  1955.0  1047.493469  1186.913018                    1205.283870
# 16  1956.0  1158.951410  1186.913018                    1191.376803
# 17  1957.0  1177.397728  1186.913018                    1176.939373
# 18  1958.0  1334.426935  1186.913018                    1188.131436
# 19  1959.0  1147.356950  1186.913018                    1201.792606
#
#        Anomaly  11 Year Moving Average Anomaly  1961-1990 Normal  \
# 0          NaN                             NaN               NaN
# 1  -172.718452                             NaN               0.0
# 2   -39.452530                             NaN               0.0
# 3     9.063881                             NaN               0.0
# 4   -12.001139                             NaN               0.0
# 5   -56.984582                             NaN               0.0
# 6   119.277277                       23.255822               0.0
# 7   120.413251                       21.330033               0.0
# 8   129.849052                        9.794733               0.0
# 9   -50.234623                       27.068379               0.0
# 10  125.200627                       15.484887               0.0
# 11   83.401276                       18.123339               0.0
# 12 -193.902125                        6.414924               0.0
# 13 -166.340836                        8.878621               0.0
# 14  199.073989                       -6.521845               0.0
# 15 -139.419549                       18.370852               0.0
# 16  -27.961608                        4.463785               0.0
# 17   -9.515290                       -9.973645               0.0
# 18  147.513917                        1.218418               0.0
# 19  -39.556069                       14.879588               0.0
#
#     1990-2019 Average  1981-2010 Normal   Unnamed: 9  Unnamed: 10  \
# 0                 NaN               NaN          NaN          NaN
# 1                79.3              60.0          NaN          NaN
# 2                79.3              60.0  1503.600000  1186.913018
# 3                79.3              60.0   914.616394  1186.913018
# 4                79.3              60.0          NaN          NaN
# 5                79.3              60.0          NaN          NaN
# 6                79.3              60.0     0.785568          NaN
# 7                79.3              60.0          NaN          NaN
# 8                79.3              60.0          NaN          NaN
# 9                79.3              60.0          NaN          NaN
# 10               79.3              60.0          NaN          NaN
# 11               79.3              60.0          NaN          NaN
# 12               79.3              60.0          NaN          NaN
# 13               79.3              60.0          NaN          NaN
# 14               79.3              60.0          NaN          NaN
# 15               79.3              60.0          NaN          NaN
# 16               79.3              60.0          NaN          NaN
# 17               79.3              60.0          NaN          NaN
# 18               79.3              60.0          NaN          NaN
# 19               79.3              60.0          NaN          NaN
#
#     Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  11 Year Average
# 0           NaN          NaN          NaN          NaN              NaN
# 1           NaN          NaN          NaN          NaN              NaN
# 2   1299.967850   316.686982  1506.913018          NaN              NaN
# 3   1115.779864  -272.296625          NaN          NaN              NaN
# 4           NaN          NaN          NaN          NaN              NaN
# 5           NaN          NaN          NaN          NaN              NaN
# 6           NaN          NaN          NaN          NaN      1210.168840
# 7           NaN          NaN          NaN          NaN      1208.243051
# 8           NaN          NaN          NaN          NaN      1196.707751
# 9           NaN          NaN          NaN          NaN      1213.981397
# 10          NaN          NaN          NaN          NaN      1202.397905
# 11          NaN          NaN          NaN          NaN      1205.036357
# 12          NaN          NaN          NaN          NaN      1193.327942
# 13          NaN          NaN          NaN          NaN      1195.791639
# 14          NaN          NaN          NaN          NaN      1180.391173
# 15          NaN          NaN          NaN          NaN      1205.283870
# 16          NaN          NaN          NaN          NaN      1191.376803
# 17          NaN          NaN          NaN          NaN      1176.939373
# 18          NaN          NaN          NaN          NaN      1188.131436
# 19          NaN          NaN          NaN          NaN      1201.792606

# %%
annualTrace = go.Bar(x=dataDF["years"],
                     y=dataDF["Anomaly"],
                     text=dataDF["ANN"],
                     name='Annual',
                     marker=dict(
    # color="#214a7b", color used in report
    color=TIMESERIES_COLOR_2,
    opacity=0.5
),
    hovertemplate='%{x}<br>' +
    '<b>Annual</b><br>' +
    'Total: %{text:.2f} mm<br>' +
    'Anomaly: %{y:.2f} mm<extra></extra>'
)
movingAverage = go.Scatter(x=dataDF["years"],
                           y=dataDF["11 Year Moving Average Anomaly"],
                           text=dataDF["11 Year Moving Average Totals"],
                           name='11yr Moving Average',
                           mode='lines',  # 'line' is default
                           line_shape='spline',
                           line=dict(
    # color="#fc0d1b", color used in report
    color=TIMESERIES_COLOR_1,
    width=2),
    hovertemplate='%{x}<br>' +
    '<b>11yr Moving Average</b><br>' +
    'Total: %{text:.2f} mm<br>' +
    'Anomaly: %{y:.2f} mm<extra></extra>'
)
normal = go.Scatter(x=dataDF["years"],
                    y=dataDF["ANNmean"],
                    name='1961-1990 Normal',
                    mode='lines',  # 'line' is default
                    line_shape='spline',
                    line=dict(color=TIMESERIES_COLOR_3, 
                              width=2),
                    hoverinfo='skip',
                    )
average1990_2019 = go.Scatter(x=dataDF["years"],
                              y=dataDF["1990-2019 Average"],
                              name='1990-2019 Average',
                              mode='lines',  # 'line' is default
                              line_shape='spline',
                              line=dict(color=TIMESERIES_COLOR_3, #""#22b2ed",  # color used in report
                                        dash='dash',
                                        width=2),
                              hoverinfo='skip',
                              )
figure_2_9 = make_subplots(specs=[[{'secondary_y': True}]])
figure_2_9.add_trace(annualTrace,
                     secondary_y=False,)
figure_2_9.add_trace(movingAverage,
                     secondary_y=False,)
figure_2_9.add_trace(normal,
                     secondary_y=True,)

figure_2_9.add_trace(average1990_2019,
                     secondary_y=False,)

figure_2_9.update_layout(TIMESERIES_LAYOUT)
figure_2_9.update_yaxes(title_text='Difference (mm) from 1961-1990 Normal',
                        secondary_y=False,
                        range=[-300, 330],
                        showgrid=False,
                        dtick=100,  # dtick sets the distance between ticks
                        tick0=0,  # tick0 sets a point to map the other ticks
                        fixedrange=True,
                        showspikes=True,
                        # zeroline=True,  # add a zero line
                        # zerolinecolor=TIMESERIES_COLOR_2
                        )
figure_2_9.update_yaxes(title_text='Annual Rainfall Total (mm)',
                        secondary_y=True,
                        range=[886, 1517],
                        showgrid=False,
                        dtick=100,  # dtick sets the distance between ticks
                        tick0=1186,  # tick0 sets a point to map the other ticks
                        fixedrange=True,
                        )

figure_2_9.update_xaxes(
    title='Year',
    fixedrange=True,
    tickformat='000',
    showspikes=True,
    spikethickness=2,
)
figure_2_9
# Out:
# <div>                            <div id="098b08ad-387b-4e81-9b4d-459b5d5ecf6a" class="plotly-graph-div" style="height:450px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("098b08ad-387b-4e81-9b4d-459b5d5ecf6a")) {                    Plotly.newPlot(                        "098b08ad-387b-4e81-9b4d-459b5d5ecf6a",                        [{"hovertemplate": "%{x}<br><b>Annual</b><br>Total: %{text:.2f} mm<br>Anomaly: %{y:.2f} mm<extra></extra>", "marker": {"color": "#E1AF00", "opacity": 0.5}, "name": "Annual", "text": [null, 1014.19456633235, 1147.46048837474, 1195.97689907682, 1174.91187884659, 1129.92843628904, 1306.19029519034, 1307.32626937543, 1316.76206975154, 1136.67839497379, 1312.11364542968, 1270.3142936517, 993.010892979257, 1020.57218201504, 1385.98700706633, 1047.49346934124, 1158.95141041714, 1177.39772766127, 1334.42693469341, 1147.35694950992, 1410.49806245726, 1159.13590722589, 1111.50256297014, 1116.12358673353, 1170.84504929337, 1291.75444922498, 1311.62524646683, 1200.34503789606, 1205.29592546159, 997.339837873262, 1185.02445577844, 914.616393606109, 1134.12235155003, 1097.95385798951, 1260.56756183041, 994.66355567586, 1070.20566588785, 1248.04905972191, 1165.73983787326, 1270.11809892865, 1296.25951817871, 1231.03942472077, 1342.75423410075, 1194.18492705721, 1155.21943953727, 1246.57931815592, 1375.73530886711, 1081.42043537725, 1323.03156200137, 1166.10554336677, 1290.03239115569, 1156.48783906998, 1226.58291400729, 1264.30810063825, 1393.38503675633, 1223.45039035788, 1181.88459938455, 1233.1925817757, 1397.35087901755, 1331.70831576248, 1342.35750940278, 1000.10238488717, 1454.46769147481, 1030.04311887395, 1179.63918822658, 1144.61440050148, 1297.71555590381, 1179.39369158879, 1409.71152552998, 1502.79919791429, 1054.52638334853, 1274.2, 1312.4, 1195.1, 1394.1, 1503.6, 1176.1, 1242.6, 1223.6, 1370.0, null, null, null, 1503.6, 914.616393606109], "type": "bar", "x": [1940.0, 1941.0, 1942.0, 1943.0, 1944.0, 1945.0, 1946.0, 1947.0, 1948.0, 1949.0, 1950.0, 1951.0, 1952.0, 1953.0, 1954.0, 1955.0, 1956.0, 1957.0, 1958.0, 1959.0, 1960.0, 1961.0, 1962.0, 1963.0, 1964.0, 1965.0, 1966.0, 1967.0, 1968.0, 1969.0, 1970.0, 1971.0, 1972.0, 1973.0, 1974.0, 1975.0, 1976.0, 1977.0, 1978.0, 1979.0, 1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, null, null, null, null], "xaxis": "x", "y": [null, -172.71845181787012, -39.452529775480116, 9.06388092659995, -12.001139303629998, -56.984581861180004, 119.27727704012, 120.41325122520993, 129.84905160131984, -50.23462317642998, 125.20062727945992, 83.40127550147986, -193.90212517096302, -166.3408361351801, 199.07398891611, -139.41954880898015, -27.961607733079973, -9.515290488950086, 147.5139165431899, -39.556068640300055, 223.58504430703988, -27.777110924330145, -75.41045518008013, -70.78943141669015, -16.06796885685003, 104.84143107475984, 124.71222831660998, 13.432019745839852, 18.38290731136999, -189.57318027695806, -1.8885623717801536, -272.29662454411107, -52.79066660018998, -88.9591601607101, 73.65454368019005, -192.24946247436003, -116.70735226237002, 61.13604157168993, -21.17318027696001, 83.20508077842987, 109.34650002849003, 44.12640657054999, 155.8412159505299, 7.271908906989893, -31.693578612949977, 59.666300005699895, 188.82229071688994, -105.49258277297008, 136.11854385114998, -20.80747478345006, 103.11937300546992, -30.425179080240014, 39.66989585706983, 77.39508248802986, 206.47201860610994, 36.53737220765993, -5.02841876567004, 46.27956362548002, 210.43786086732985, 144.7952976122599, 155.4444912525 ...

# %%
# used for static images on main site
figure_2_9.update_layout(
    margin={"t": 40, "b": 20, "r": 40, "l": 80, },
    plot_bgcolor='#f7fbfd',
    paper_bgcolor='white',
    height=500,
    width=900,
    font_size=14,
    title=dict(
        text='<b>Mean Annual Precipitation - Ireland (1941-2019)</b>',
        x=0.5,
        y=0.97),)
figure_2_9.update_yaxes(
    secondary_y=False,
    title_standoff=0.2
)
figure_2_9.update_xaxes(
    title_standoff=1
)
figure_2_9.write_image(
    "/Users/dan/ClimateIreland/CI-Status-Report/images/mean__annual__precipitation.png", 
    format="png"
    )

# %%
data_path = DATA_PATH+'Atmospheric_Domain/2.5Precipitation/Figure2.10/'
df = pd.read_csv(data_path+'Fig2.10_StationsTable.txt', delimiter = ",")
df=df.round(2) 
df
# Out:
#    FID   station_id    lat    lon  stno  min_year  max_year  Number_of  \
# 0    2    Belmullet  54.23 -10.01  2375      1956      2019         64
# 1    3     Casement  53.31  -6.44  3723      1964      2019         56
# 2    4  Claremorris  53.71  -8.99  2175      1950      2019         70
# 3    5      CorkApt  51.85  -8.49  3904      1962      2019         58
# 4    6    DublinApt  53.43  -6.24   532      1948      2019         79
# 5   13    MalinHead  55.37  -7.34  1575      1969      2019         65
# 6   17    Mullingar  53.54  -7.36   875      1994      2019         47
# 7   21     RochesPt  51.79  -8.24  1075      1949      2019         65
# 8   22   ShannonApt  52.69  -8.92   518      1941      2019         75
# 9   24     Valentia  51.94 -10.24  2275      1939      2019         81
#
#    CDD_decade  CWD_decade  CDD_year  CWD_year
# 0        0.06        1.14      0.01      0.12
# 1        1.11        0.76     -0.05      0.02
# 2       -0.38        0.50     -0.03      0.07
# 3        0.71        1.03     -0.03      0.05
# 4       -0.08        0.00      0.00      0.01
# 5       -0.17        1.23     -0.00      0.11
# 6        1.30        1.32     -0.03      0.08
# 7       -2.81       -0.63     -0.02      0.04
# 8       -0.27        0.19     -0.02      0.02
# 9       -0.43        1.21     -0.02      0.09

# %%
cwd1DF = df.loc[df['CWD_decade']<= 0]
cwd1DFStr=cwd1DF.astype(str)
cwd1Trend = go.Scattermapbox(
        name='<= 0.0',
        lon=cwd1DF.lon,
        lat=cwd1DF.lat,
        marker=dict(color="#4ce600",#green
                    size=8,),
        hovertemplate='<b>'+cwd1DF["station_id"]+'</b><br>' +
       'Trend in CWD per Decade: ' + cwd1DFStr["CWD_decade"]+ ' days<br>' +
        'Trend in CWD per Year: ' + cwd1DFStr["CWD_year"]+' days<br>' +
        'Lat: ' + cwd1DFStr["lat"]+ '\u00b0<br>' +
        'Lon: ' + cwd1DFStr["lon"]+ '\u00b0<br>' +
        '<extra><br>'+
        'Trend in CDD per Decade: ' + cwd1DFStr["CDD_decade"]+' days<br>' +
        'Trend in CDD per Year: ' + cwd1DFStr["CDD_year"]+' days<br>' +
        '</extra>',
    )

cwd2DF = df.loc[(df['CWD_decade']>0)&(df['CWD_decade']<=0.5)]
cwd2DFStr=cwd2DF.astype(str)
cwd2Trend = go.Scattermapbox(
        name='> 0.0, <= 0.5',
        lon=cwd2DF.lon,
        lat=cwd2DF.lat,
        marker=dict(color="#004da8",#blue
                    size=10,),
        hovertemplate='<b>'+cwd2DFStr["station_id"]+'</b><br>' +
       'Trend in CWD per Decade: ' + cwd2DFStr["CWD_decade"]+' days<br>' +
        'Trend in CWD per Year: ' + cwd2DFStr["CWD_year"]+' days<br>' +
        'Lat: ' + cwd2DFStr["lat"]+ '\u00b0<br>' +
        'Lon: ' + cwd2DFStr["lon"]+ '\u00b0<br>' +
        'Trend in CDD per Decade: ' + cwd2DFStr["CDD_decade"]+' days<br>' +
        'Trend in CDD per Year: ' + cwd2DFStr["CDD_year"]+' days<br>' +
        '<extra></extra>',
    )
cwd3DF = df.loc[(df['CWD_decade']>0.5)&(df['CWD_decade']<=1)]
cwd3DFStr=cwd3DF.astype(str)
cwd3Trend = go.Scattermapbox(
        name='> 0.5, <= 1.0',
        lon=cwd3DF.lon,
        lat=cwd3DF.lat,
        marker=dict(color="#a900e6",#pink
                    size=12,),
        hovertemplate='<b>'+cwd3DFStr["station_id"]+'</b><br>' +
       'Trend in CWD per Decade: ' + cwd3DFStr["CWD_decade"]+' days<br>' +
        'Trend in CWD per Year: ' + cwd3DFStr["CWD_year"]+' days<br>' +
        'Lat: ' + cwd3DFStr["lat"]+ '\u00b0<br>' +
        'Lon: ' + cwd3DFStr["lon"]+ '\u00b0<br>' +
        'Trend in CDD per Decade: ' + cwd3DFStr["CDD_decade"]+' days<br>' +
        'Trend in CDD per Year: ' + cwd3DFStr["CDD_year"]+' days<br>' +
        '<extra></extra>',
    )
cwd4DF = df.loc[df['CWD_decade']>1.0]
cwd4DFStr=cwd4DF.astype(str)
cwd4Trend = go.Scattermapbox(
        name='> 1.0',
        lon=cwd4DF.lon,
        lat=cwd4DF.lat,
        marker=dict(color="#4c0073",#purple
                    size=14,),
        hovertemplate='<b>'+cwd4DFStr["station_id"]+'</b><br>' +
       'Trend in CWD per Decade: ' + cwd4DFStr["CWD_decade"]+' days<br>' +
        'Trend in CWD per Year: ' + cwd4DFStr["CWD_year"]+' days<br>' +
        'Lat: ' + cwd4DFStr["lat"]+ '\u00b0<br>' +
        'Lon: ' + cwd4DFStr["lon"]+ '\u00b0<br>' +
        'Trend in CDD per Decade: ' + cwd4DFStr["CDD_decade"]+' days<br>' +
        'Trend in CDD per Year: ' + cwd4DFStr["CDD_year"]+' days<br>' +
        '<extra></extra>',
    )

# %%
figure_2_10_1 = go.Figure(
        data=[cwd1Trend,cwd2Trend,cwd3Trend,cwd4Trend],
        layout=MAP_LAYOUT)
figure_2_10_1.update_layout(legend_title="<b>Trend in maximum length of"+
                      "<br>annual wet spell days (CWD) per decade</b>")
figure_2_10_1
# Out:
# <div>                            <div id="5defe39f-c4cb-441c-95b9-8345ab2fb622" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5defe39f-c4cb-441c-95b9-8345ab2fb622")) {                    Plotly.newPlot(                        "5defe39f-c4cb-441c-95b9-8345ab2fb622",                        [{"hovertemplate": ["<b>DublinApt</b><br>Trend in CWD per Decade: 0.0 days<br>Trend in CWD per Year: 0.01 days<br>Lat: 53.43\u00b0<br>Lon: -6.24\u00b0<br><extra><br>Trend in CDD per Decade: -0.08 days<br>Trend in CDD per Year: 0.0 days<br></extra>", "<b>RochesPt</b><br>Trend in CWD per Decade: -0.63 days<br>Trend in CWD per Year: 0.04 days<br>Lat: 51.79\u00b0<br>Lon: -8.24\u00b0<br><extra><br>Trend in CDD per Decade: -2.81 days<br>Trend in CDD per Year: -0.02 days<br></extra>"], "lat": [53.43, 51.79], "lon": [-6.24, -8.24], "marker": {"color": "#4ce600", "size": 8}, "name": "<= 0.0", "type": "scattermapbox"}, {"hovertemplate": ["<b>Claremorris</b><br>Trend in CWD per Decade: 0.5 days<br>Trend in CWD per Year: 0.07 days<br>Lat: 53.71\u00b0<br>Lon: -8.99\u00b0<br>Trend in CDD per Decade: -0.38 days<br>Trend in CDD per Year: -0.03 days<br><extra></extra>", "<b>ShannonApt</b><br>Trend in CWD per Decade: 0.19 days<br>Trend in CWD per Year: 0.02 days<br>Lat: 52.69\u00b0<br>Lon: -8.92\u00b0<br>Trend in CDD per Decade: -0.27 days<br>Trend in CDD per Year: -0.02 days<br><extra></extra>"], "lat": [53.71, 52.69], "lon": [-8.99, -8.92], "marker": {"color": "#004da8", "size": 10}, "name": "> 0.0, <= 0.5", "type": "scattermapbox"}, {"hovertemplate": ["<b>Casement</b><br>Trend in CWD per Decade: 0.76 days<br>Trend in CWD per Year: 0.02 days<br>Lat: 53.31\u00b0<br>Lon: -6.44\u00b0<br>Trend in CDD per Decade: 1.11 days<br>Trend in CDD per Year: -0.05 days<br><extra></extra>"], "lat": [53.31], "lon": [-6.44], "marker": {"color": "#a900e6", "size": 12}, "name": "> 0.5, <= 1.0", "type": "scattermapbox"}, {"hovertemplate": ["<b>Belmullet</b><br>Trend in CWD per Decade: 1.14 days<br>Trend in CWD per Year: 0.12 days<br>Lat: 54.23\u00b0<br>Lon: -10.01\u00b0<br>Trend in CDD per Decade: 0.06 days<br>Trend in CDD per Year: 0.01 days<br><extra></extra>", "<b>CorkApt</b><br>Trend in CWD per Decade: 1.03 days<br>Trend in CWD per Year: 0.05 days<br>Lat: 51.85\u00b0<br>Lon: -8.49\u00b0<br>Trend in CDD per Decade: 0.71 days<br>Trend in CDD per Year: -0.03 days<br><extra></extra>", "<b>MalinHead</b><br>Trend in CWD per Decade: 1.23 days<br>Trend in CWD per Year: 0.11 days<br>Lat: 55.37\u00b0<br>Lon: -7.34\u00b0<br>Trend in CDD per Decade: -0.17 days<br>Trend in CDD per Year: -0.0 days<br><extra></extra>", "<b>Mullingar</b><br>Trend in CWD per Decade: 1.32 days<br>Trend in CWD per Year: 0.08 days<br>Lat: 53.54\u00b0<br>Lon: -7.36\u00b0<br>Trend in CDD per Decade: 1.3 days<br>Trend in CDD per Year: -0.03 days<br><extra></extra>", "<b>Valentia</b><br>Trend in CWD per Decade: 1.21 days<br>Trend in CWD per Year: 0.09 days<br>Lat: 51.94\u00b0<br>Lon: -10.24\u00b0<br>Trend in CDD per Decade: -0.43 days<br>Trend in CDD per Year: -0.02 days<br><extra></extra>"], "lat": [54.23, 51.85, 55.37, 53.54, 51.94], "lon": [-10.01, -8.49, -7.34, -7.36, -10.24], "marker": {"color": "#4c0073", "size": 14}, "name": "> 1.0", "type": "scattermapbox"}],                        {"height": 400, "legend": {"title": {"text": "<b>Trend in maximum length of<br>annual wet spell days (CWD) per decade</b>"}, "x": 0.01}, "mapbox": {"bearing": 0, "center": {"lat": 53.4, "lon": 352}, "pitch": 0, "style": "open-street-map", "zoom": 5}, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "paper_bgcolor": "rgba(0,0,0,0)", "plot_bgcolor": "rgba(0,0,0,0)", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6",  ...

# %%
cdd1DF = df.loc[df['CDD_decade']<= 0]
cdd1DFStr=cdd1DF.astype(str)
cdd1Trend = go.Scattermapbox(
        name='<= 0.0',
        lon=cdd1DF.lon,
        lat=cdd1DF.lat,
        marker=dict(color="#70a800",#green
                    size=8,),
        hovertemplate='<b>'+cdd1DF["station_id"]+'</b><br>' +
       'Trend in CDD per Decade: ' + cdd1DFStr["CDD_decade"]+ ' days<br>' +
        'Trend in CDD per Year: ' + cdd1DFStr["CDD_year"]+' days<br>' +
        'Lat: ' + cdd1DFStr["lat"]+ '\u00b0<br>' +
        'Lon: ' + cdd1DFStr["lon"]+ '\u00b0<br>' +
        '<extra><br>'+
        'Trend in CWD per Decade: ' + cdd1DFStr["CWD_decade"]+' days<br>' +
        'Trend in CWD per Year: ' + cdd1DFStr["CWD_year"]+' days<br>' +
        '</extra>',
    )

cdd2DF = df.loc[(df['CDD_decade']>0)&(df['CDD_decade']<=0.5)]
cdd2DFStr=cdd2DF.astype(str)
cdd2Trend = go.Scattermapbox(
        name='> 0.0, <= 0.5',
        lon=cdd2DF.lon,
        lat=cdd2DF.lat,
        marker=dict(color="#ffff00",#yellow
                    size=10,),
        hovertemplate='<b>'+cdd2DFStr["station_id"]+'</b><br>' +
       'Trend in CDD per Decade: ' + cdd2DFStr["CDD_decade"]+' days<br>' +
        'Trend in CDD per Year: ' + cdd2DFStr["CDD_year"]+' days<br>' +
        'Lat: ' + cdd2DFStr["lat"]+ '\u00b0<br>' +
        'Lon: ' + cdd2DFStr["lon"]+ '\u00b0<br>' +
        'Trend in CWD per Decade: ' + cdd2DFStr["CWD_decade"]+' days<br>' +
        'Trend in CWD per Year: ' + cdd2DFStr["CWD_year"]+' days<br>' +
        '<extra></extra>',
    )
cdd3DF = df.loc[(df['CDD_decade']>0.5)&(df['CDD_decade']<=1)]
cdd3DFStr=cdd3DF.astype(str)
cdd3Trend = go.Scattermapbox(
        name='> 0.5, <= 1.0',
        lon=cdd3DF.lon,
        lat=cdd3DF.lat,
        marker=dict(color="#e69800",#orange
                    size=12,),
        hovertemplate='<b>'+cdd3DFStr["station_id"]+'</b><br>' +
       'Trend in CDD per Decade: ' + cdd3DFStr["CDD_decade"]+' days<br>' +
        'Trend in CDD per Year: ' + cdd3DFStr["CDD_year"]+' days<br>' +
        'Lat: ' + cdd3DFStr["lat"]+ '\u00b0<br>' +
        'Lon: ' + cdd3DFStr["lon"]+ '\u00b0<br>' +
        'Trend in CWD per Decade: ' + cdd3DFStr["CWD_decade"]+' days<br>' +
        'Trend in CWD per Year: ' + cdd3DFStr["CWD_year"]+' days<br>' +
        '<extra></extra>',
    )
cdd4DF = df.loc[df['CDD_decade']>1.0]
cdd4DFStr=cdd4DF.astype(str)
cdd4Trend = go.Scattermapbox(
        name='> 1.0',
        lon=cdd4DF.lon,
        lat=cdd4DF.lat,
        marker=dict(color="#e60000",#red
                    size=14,),
        hovertemplate='<b>'+cdd4DFStr["station_id"]+'</b><br>' +
       'Trend in CDD per Decade: ' + cdd4DFStr["CDD_decade"]+' days<br>' +
        'Trend in CDD per Year: ' + cdd4DFStr["CDD_year"]+' days<br>' +
        'Lat: ' + cdd4DFStr["lat"]+ '\u00b0<br>' +
        'Lon: ' + cdd4DFStr["lon"]+ '\u00b0<br>' +
        'Trend in CWD per Decade: ' + cdd4DFStr["CWD_decade"]+' days<br>' +
        'Trend in CWD per Year: ' + cdd4DFStr["CWD_year"]+' days<br>' +
        '<extra></extra>',
    )

# %%
figure_2_10_2 = go.Figure(
        data=[cdd1Trend,cdd2Trend,cdd3Trend,cdd4Trend],
        layout=MAP_LAYOUT)
figure_2_10_2.update_layout(legend_title="<b>Trend in maximum length of"+
                      "<br>annual dry spell days (CDD) per decade</b>")
figure_2_10_2
# Out:
# <div>                            <div id="5591e614-24f9-4fa1-b1cc-0b2b10375305" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5591e614-24f9-4fa1-b1cc-0b2b10375305")) {                    Plotly.newPlot(                        "5591e614-24f9-4fa1-b1cc-0b2b10375305",                        [{"hovertemplate": ["<b>Claremorris</b><br>Trend in CDD per Decade: -0.38 days<br>Trend in CDD per Year: -0.03 days<br>Lat: 53.71\u00b0<br>Lon: -8.99\u00b0<br><extra><br>Trend in CWD per Decade: 0.5 days<br>Trend in CWD per Year: 0.07 days<br></extra>", "<b>DublinApt</b><br>Trend in CDD per Decade: -0.08 days<br>Trend in CDD per Year: 0.0 days<br>Lat: 53.43\u00b0<br>Lon: -6.24\u00b0<br><extra><br>Trend in CWD per Decade: 0.0 days<br>Trend in CWD per Year: 0.01 days<br></extra>", "<b>MalinHead</b><br>Trend in CDD per Decade: -0.17 days<br>Trend in CDD per Year: -0.0 days<br>Lat: 55.37\u00b0<br>Lon: -7.34\u00b0<br><extra><br>Trend in CWD per Decade: 1.23 days<br>Trend in CWD per Year: 0.11 days<br></extra>", "<b>RochesPt</b><br>Trend in CDD per Decade: -2.81 days<br>Trend in CDD per Year: -0.02 days<br>Lat: 51.79\u00b0<br>Lon: -8.24\u00b0<br><extra><br>Trend in CWD per Decade: -0.63 days<br>Trend in CWD per Year: 0.04 days<br></extra>", "<b>ShannonApt</b><br>Trend in CDD per Decade: -0.27 days<br>Trend in CDD per Year: -0.02 days<br>Lat: 52.69\u00b0<br>Lon: -8.92\u00b0<br><extra><br>Trend in CWD per Decade: 0.19 days<br>Trend in CWD per Year: 0.02 days<br></extra>", "<b>Valentia</b><br>Trend in CDD per Decade: -0.43 days<br>Trend in CDD per Year: -0.02 days<br>Lat: 51.94\u00b0<br>Lon: -10.24\u00b0<br><extra><br>Trend in CWD per Decade: 1.21 days<br>Trend in CWD per Year: 0.09 days<br></extra>"], "lat": [53.71, 53.43, 55.37, 51.79, 52.69, 51.94], "lon": [-8.99, -6.24, -7.34, -8.24, -8.92, -10.24], "marker": {"color": "#70a800", "size": 8}, "name": "<= 0.0", "type": "scattermapbox"}, {"hovertemplate": ["<b>Belmullet</b><br>Trend in CDD per Decade: 0.06 days<br>Trend in CDD per Year: 0.01 days<br>Lat: 54.23\u00b0<br>Lon: -10.01\u00b0<br>Trend in CWD per Decade: 1.14 days<br>Trend in CWD per Year: 0.12 days<br><extra></extra>"], "lat": [54.23], "lon": [-10.01], "marker": {"color": "#ffff00", "size": 10}, "name": "> 0.0, <= 0.5", "type": "scattermapbox"}, {"hovertemplate": ["<b>CorkApt</b><br>Trend in CDD per Decade: 0.71 days<br>Trend in CDD per Year: -0.03 days<br>Lat: 51.85\u00b0<br>Lon: -8.49\u00b0<br>Trend in CWD per Decade: 1.03 days<br>Trend in CWD per Year: 0.05 days<br><extra></extra>"], "lat": [51.85], "lon": [-8.49], "marker": {"color": "#e69800", "size": 12}, "name": "> 0.5, <= 1.0", "type": "scattermapbox"}, {"hovertemplate": ["<b>Casement</b><br>Trend in CDD per Decade: 1.11 days<br>Trend in CDD per Year: -0.05 days<br>Lat: 53.31\u00b0<br>Lon: -6.44\u00b0<br>Trend in CWD per Decade: 0.76 days<br>Trend in CWD per Year: 0.02 days<br><extra></extra>", "<b>Mullingar</b><br>Trend in CDD per Decade: 1.3 days<br>Trend in CDD per Year: -0.03 days<br>Lat: 53.54\u00b0<br>Lon: -7.36\u00b0<br>Trend in CWD per Decade: 1.32 days<br>Trend in CWD per Year: 0.08 days<br><extra></extra>"], "lat": [53.31, 53.54], "lon": [-6.44, -7.36], "marker": {"color": "#e60000", "size": 14}, "name": "> 1.0", "type": "scattermapbox"}],                        {"height": 400, "legend": {"title": {"text": "<b>Trend in maximum length of<br>annual dry spell days (CDD) per decade</b>"}, "x": 0.01}, "mapbox": {"bearing": 0, "center": {"lat": 53.4, "lon": 352}, "pitch": 0, "style": "open-street-map", "zoom": 5}, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "paper_bgcolor": "rgba(0,0,0,0)", "plot_bgcolor": "rgba(0,0,0,0)", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"col ...

# %%
df.loc[df['CWD_decade']<=0,'group']=1
df.loc[(df['CWD_decade']>0)&(df['CWD_decade']<=0.5),'group']=2
df.loc[(df['CWD_decade']>0.5)&(df['CWD_decade']<1),'group']=3
df.loc[df['CWD_decade']>=1.0,'group']=4
df
# Out:
#    FID   station_id        lat       lon  stno  min_year  max_year  Number_of  \
# 0    2    Belmullet  54.227501 -10.00694  2375      1956      2019         64
# 1    3     Casement  53.305561  -6.43889  3723      1964      2019         56
# 2    4  Claremorris  53.710831  -8.99250  2175      1950      2019         70
# 3    5      CorkApt  51.847221  -8.48611  3904      1962      2019         58
# 4    6    DublinApt  53.427780  -6.24083   532      1948      2019         79
# 5   13    MalinHead  55.371941  -7.33917  1575      1969      2019         65
# 6   17    Mullingar  53.537220  -7.36222   875      1994      2019         47
# 7   21     RochesPt  51.793060  -8.24444  1075      1949      2019         65
# 8   22   ShannonApt  52.690281  -8.91806   518      1941      2019         75
# 9   24     Valentia  51.938332 -10.24083  2275      1939      2019         81
#
#    CDD_decade  CWD_decade  CDD_year  CWD_year  group
# 0    0.060000    1.137143  0.007051  0.123649    4.0
# 1    1.108571    0.762857 -0.052597  0.021360    3.0
# 2   -0.380000    0.500000 -0.028869  0.069793    2.0
# 3    0.708571    1.031429 -0.028515  0.054939    4.0
# 4   -0.080000    0.000000  0.003262  0.007035    1.0
# 5   -0.168571    1.225714 -0.001049  0.109484    4.0
# 6    1.300000    1.320000 -0.026364  0.076434    4.0
# 7   -2.811429   -0.634286 -0.024329  0.041829    1.0
# 8   -0.271429    0.191429 -0.024296  0.016273    2.0
# 9   -0.428571    1.214286 -0.022425  0.086969    4.0

# %%
# colors = ["purple","pink","blue","green"]
colors=["#4c0073","#a900e6","#004da8","#4ce600"]
wetDayTrend = go.Scattermapbox(
        name='Wet Days',
        lon=df.lon,
        lat=df.lat,
        text=df['CWD_decade'],
        marker=dict(color=df['group'],
                    colorscale=colors,
                    size=df['group']*8,
                    reversescale=True,
                    showscale=False,
                    colorbar=dict(title="Days")),
        hovertemplate=df.station_id +
        '<br>Lat: %{lon:.2f}\u00b0<br>' +
        'Lon: %{lat:.2f}\u00b0<br>' +
        'CWD: %{text:.1f} days<br>' +
        '<extra></extra>',
    )
map_2_5 = go.Figure(
        data=[wetDayTrend],
        layout=MAP_LAYOUT)
map_2_5.update_layout(
        autosize=True,
        xaxis={'title': 'x-axis','fixedrange':True},
        yaxis={'title': 'y-axis','fixedrange':True},
        mapbox=dict(bearing=0,
                center=dict(
                    lat=53.5,
                    lon=352
                ),
                pitch=0,
                zoom=5.2,)
)
map_2_5.add_shape(type="circle",
    xref="paper", yref="paper",
    x0=0.1, y0=0.8, x1=0.2, y1=1,
    line_color="LightSeaGreen",
)
map_2_5.add_annotation(
    xref="paper", yref="paper",
    x=0.1,
    y=0.8,
    showarrow=False,
    text="An annotation whose text and arrowhead reference the axes and the data",
)

map_2_5
# Out:
# <div>                            <div id="7ae5421d-1819-4903-bb6f-7d961266187d" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ae5421d-1819-4903-bb6f-7d961266187d")) {                    Plotly.newPlot(                        "7ae5421d-1819-4903-bb6f-7d961266187d",                        [{"hovertemplate": ["Belmullet<br>Lat: %{lon:.2f}\u00b0<br>Lon: %{lat:.2f}\u00b0<br>CWD: %{text:.1f} days<br><extra></extra>", "Casement<br>Lat: %{lon:.2f}\u00b0<br>Lon: %{lat:.2f}\u00b0<br>CWD: %{text:.1f} days<br><extra></extra>", "Claremorris<br>Lat: %{lon:.2f}\u00b0<br>Lon: %{lat:.2f}\u00b0<br>CWD: %{text:.1f} days<br><extra></extra>", "CorkApt<br>Lat: %{lon:.2f}\u00b0<br>Lon: %{lat:.2f}\u00b0<br>CWD: %{text:.1f} days<br><extra></extra>", "DublinApt<br>Lat: %{lon:.2f}\u00b0<br>Lon: %{lat:.2f}\u00b0<br>CWD: %{text:.1f} days<br><extra></extra>", "MalinHead<br>Lat: %{lon:.2f}\u00b0<br>Lon: %{lat:.2f}\u00b0<br>CWD: %{text:.1f} days<br><extra></extra>", "Mullingar<br>Lat: %{lon:.2f}\u00b0<br>Lon: %{lat:.2f}\u00b0<br>CWD: %{text:.1f} days<br><extra></extra>", "RochesPt<br>Lat: %{lon:.2f}\u00b0<br>Lon: %{lat:.2f}\u00b0<br>CWD: %{text:.1f} days<br><extra></extra>", "ShannonApt<br>Lat: %{lon:.2f}\u00b0<br>Lon: %{lat:.2f}\u00b0<br>CWD: %{text:.1f} days<br><extra></extra>", "Valentia<br>Lat: %{lon:.2f}\u00b0<br>Lon: %{lat:.2f}\u00b0<br>CWD: %{text:.1f} days<br><extra></extra>"], "lat": [54.22750092, 53.30556107, 53.71083069, 51.84722137, 53.42778015, 55.37194061, 53.53722, 51.7930603, 52.69028091, 51.9383316], "lon": [-10.00693989, -6.43888998, -8.992500305, -8.486109734, -6.240829945, -7.339169979, -7.36221981, -8.244440079, -8.918060303, -10.24083042], "marker": {"color": [4.0, 3.0, 2.0, 4.0, 1.0, 4.0, 4.0, 1.0, 2.0, 4.0], "colorbar": {"title": {"text": "Days"}}, "colorscale": [[0.0, "#4c0073"], [0.3333333333333333, "#a900e6"], [0.6666666666666666, "#004da8"], [1.0, "#4ce600"]], "reversescale": true, "showscale": false, "size": [32.0, 24.0, 16.0, 32.0, 8.0, 32.0, 32.0, 8.0, 16.0, 32.0]}, "name": "Wet Days", "text": [1.137142857, 0.762857143, 0.5, 1.031428571, 0.0, 1.225714286, 1.32, -0.634285714, 0.191428571, 1.214285714], "type": "scattermapbox"}],                        {"annotations": [{"showarrow": false, "text": "An annotation whose text and arrowhead reference the axes and the data", "x": 0.1, "xref": "paper", "y": 0.8, "yref": "paper"}], "height": 400, "legend": {"title": {"text": "<b>Station Type</b>"}, "x": 0.01}, "mapbox": {"bearing": 0, "center": {"lat": 53.5, "lon": 352}, "pitch": 0, "style": "open-street-map", "zoom": 5.2}, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "paper_bgcolor": "rgba(0,0,0,0)", "plot_bgcolor": "rgba(0,0,0,0)", "shapes": [{"line": {"color": "LightSeaGreen"}, "type": "circle", "x0": 0.1, "x1": 0.2, "xref": "paper", "y0": 0.8, "y1": 1, "yref": "paper"}], "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953" ...

# %%
data_path = DATA_PATH+'Atmospheric_Domain/2.5Precipitation/Map2.5/'
dataDF = pd.read_csv(data_path+'Map2.5_StationTable.txt', delimiter = ",")
dataDF
# Out:
#      FID   County  Station_Nu                    name  Height__m_  Easting  \
# 0      0   Carlow         375                Oak_Park          62   273000
# 1      1   Carlow        2115  HACKETSTOWN_(Voc.Sch.)         189   297500
# 2      2   Carlow        4415     TULLOW_(Waterworks)          76   284700
# 3      3   Carlow        4515  TULLOW_(Ardoyne_Glebe)          79   288200
# 4      4   Carlow        6114    POLLMOUNTY FISH FARM          24   274500
# ..   ...      ...         ...                     ...         ...      ...
# 515  515  Wicklow        9820           M.LOUGH OULER         457   309693
# 516  516  Wicklow       19023           M.BALLINATONA         297   305300
# 517  517  Wicklow       19323         M.MOANBANE NO.1         500   303300
# 518  518  Wicklow       19523         M.MOANBANE NO.4         354   304400
# 519  519  Wicklow       19723             M.SALLY GAP         462   312600
#
#      Northing  Latitude  Longitude  Open_Year Close_Year      Type
# 0      179500    52.857     -6.909       2003             Synoptic
# 1      179900    52.857     -6.552       1949             Rainfall
# 2      173400    52.803     -6.739       1985             Rainfall
# 3      169800    52.770     -6.689       1985             Rainfall
# 4      135545    52.467     -6.902       1987             Rainfall
# ..        ...       ...        ...        ...        ...       ...
# 515    202757    53.059     -6.359       1965             Rainfall
# 516    213300    53.158     -6.422       1937             Rainfall
# 517    204700    53.083     -6.455       1937             Rainfall
# 518    205100    53.085     -6.438       1937             Rainfall
# 519    211100    53.137     -6.317       1937             Rainfall
#
# [520 rows x 12 columns]

# %%
data_path = DATA_PATH+'Atmospheric_Domain/2.5Precipitation/Map2.5/'
dataDF = pd.read_csv(data_path+'Map2.5_StationTable.txt', delimiter = ",")
map_2_5=stations_map(dataDF)
map_2_5
# Out:
# <div>                            <div id="6b1db79c-7b12-408e-9edd-ab502602fe54" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b1db79c-7b12-408e-9edd-ab502602fe54")) {                    Plotly.newPlot(                       "6b1db79c-7b12-408e-9edd-ab502602fe54",                        [{"hovertemplate": [], "lat": [], "lon": [], "marker": {"color": "Yellow", "size": 7}, "name": "Buoys", "type": "scattermapbox"}, {"hovertemplate": ["Name: Oak_Park<br>Type: Synoptic<br>Station No.: 375<br>County.: Carlow<br>Open Year.: 2003<br>Height: 62.00m<br>Easting: 273000<br>Northing: 179500<br>Lat: 52.86\u00b0<br>Lon: 52.86\u00b0<br><extra></extra>", "Name: Ballyhaise<br>Type: Synoptic<br>Station No.: 675<br>County.: Cavan<br>Open Year.: 2003<br>Height: 78.00m<br>Easting: 245200<br>Northing: 311600<br>Lat: 54.05\u00b0<br>Lon: 54.05\u00b0<br><extra></extra>", "Name: Shannon_Airport<br>Type: Synoptic<br>Station No.: 518<br>County.: Clare<br>Open Year.: 1937<br>Height: 15.00m<br>Easting: 137900<br>Northing: 160300<br>Lat: 52.69\u00b0<br>Lon: 52.69\u00b0<br><extra></extra>", "Name: Moore_Park<br>Type: Synoptic<br>Station No.: 575<br>County.: Cork<br>Open Year.: 2003<br>Height: 46.00m<br>Easting: 181900<br>Northing: 101400<br>Lat: 52.16\u00b0<br>Lon: 52.16\u00b0<br><extra></extra>", "Name: SherkinIsland<br>Type: Synoptic<br>Station No.: 775<br>County.: Cork<br>Open Year.: 2004<br>Height: 21.00m<br>Easting: 100781<br>Northing: 25801<br>Lat: 51.47\u00b0<br>Lon: 51.47\u00b0<br><extra></extra>", "Name: Roches_Point<br>Type: Synoptic<br>Station No.: 1075<br>County.: Cork<br>Open Year.: 2004<br>Height: 40.00m<br>Easting: 182779<br>Northing: 60625<br>Lat: 51.79\u00b0<br>Lon: 51.79\u00b0<br><extra></extra>", "Name: Cork_Airport<br>Type: Synoptic<br>Station No.: 3904<br>County.: Cork<br>Open Year.: 1961<br>Height: 155.00m<br>Easting: 166500<br>Northing: 66200<br>Lat: 51.84\u00b0<br>Lon: 51.84\u00b0<br><extra></extra>", "Name: Malin_head<br>Type: Synoptic<br>Station No.: 1575<br>County.: Donegal<br>Open Year.: 2009<br>Height: 20.00m<br>Easting: 241939<br>Northing: 458562<br>Lat: 55.37\u00b0<br>Lon: 55.37\u00b0<br><extra></extra>", "Name: Finner<br>Type: Synoptic<br>Station No.: 2075<br>County.: Donegal<br>Open Year.: 2010<br>Height: 33.00m<br>Easting: 184300<br>Northing: 360635<br>Lat: 54.49\u00b0<br>Lon: 54.49\u00b0<br><extra></extra>", "Name: PhoenixPark<br>Type: Synoptic<br>Station No.: 175<br>County.: Dublin<br>Open Year.: 2003<br>Height: 48.00m<br>Easting: 310000<br>Northing: 236100<br>Lat: 53.36\u00b0<br>Lon: 53.36\u00b0<br><extra></extra>", "Name: Dublin_Airport<br>Type: Synoptic<br>Station No.: 532<br>County.: Dublin<br>Open Year.: 1939<br>Height: 71.00m<br>Easting: 316900<br>Northing: 243400<br>Lat: 53.42\u00b0<br>Lon: 53.42\u00b0<br><extra></extra>", "Name: Casement<br>Type: Synoptic<br>Station No.: 3723<br>County.: Dublin<br>Open Year.: 1944<br>Height: 91.00m<br>Easting: 304100<br>Northing: 229500<br>Lat: 53.30\u00b0<br>Lon: 53.30\u00b0<br><extra></extra>", "Name: Mace_Head<br>Type: Synoptic<br>Station No.: 275<br>County.: Galway<br>Open Year.: 2003<br>Height: 21.00m<br>Easting: 73400<br>Northing: 232276<br>Lat: 53.32\u00b0<br>Lon: 53.32\u00b0<br><extra></extra>", "Name: Athenry<br>Type: Synoptic<br>Station No.: 1875<br>County.: Galway<br>Open Year.: 2010<br>Height: 40.00m<br>Easting: 147659<br>Northing: 226804<br>Lat: 53.29\u00b0<br>Lon: 53.29\u00b0<br><extra></extra>", "Name: Valentia_Observatory<br>Type: Synoptic<br>Station No.: 2275<br>County.: Kerry<br>Open Year.: 2010<br>Height: 24.00m<br>Easting: 45940<br>Northing: 78555<br>Lat: 51.94\u00b0<br>Lon: 51.94\u00b0<br><extra></extra>", "Name: Newport<br>Type: Synoptic<br>Station No.: 1175<br>County.: Mayo<br>Open Year.: 2005<br>Height: 22.00m<br>Easting ...
